# %% [markdown]
# ## <span class="motutor-highlight motutor-id_ql5k8b6-id_qcgmbvh"><i></i>计算方差</span>
#
# * 方差是衡量随机变量或一组数据时离散程度的度量，它描述随机变量对于数学期望的偏离程度，是各个样本数据和平均数之差的平方和的平均数
# $$
# \sigma^2 = \frac {\sum(X-\mu)^2 }{n}
# $$
# * 这里，$\mu$是均值
# * 显然，要计算方差，需要先计算出均值，然后用之前读到的每一个值去减均值，所以，需要记录读到的每一个值

# %% [markdown]
# ## 记录每一个读入的数

# %%
s=cnt=0
while True:
    x = int(input())
    if x == -1:
        break
    cnt += 1
    s += x
print(s/cnt)

# %% [markdown]
# * 之前的代码不记录，读入x之后，累加，然后就丢弃了
# * 一个变量只能记录一个数值，再次赋值就把原来的值丢弃了
# * 如何记录很多数值？

# %% [markdown]
# 下一页我们来学习Python里另一种常见数据类型——列表
