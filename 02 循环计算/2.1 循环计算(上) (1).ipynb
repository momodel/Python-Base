# %% [markdown]
# <center style="font-size:30px">循环计算（上）</center>

# %% [markdown]
# ## 程序
#
# 是由三种东西组成的：
#
# * 定义：如函数定义
# * 计算：如`3.14*radius**2`、`print(area)`
# * 语句：如
#
# ```python
# if diff_minute<0:
#     diff_minute += 60
#     diff_hour -= 1
# ```

# %% [markdown]
# ## 计算
#
# 回顾一下：
# * 表达式：计算的式子
# * 表达式是由算子和运算符组成的
#    * 单个算子也是一个表达式
#    * 函数调用是一个算子，因此也是一个表达式
