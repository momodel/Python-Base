# %% [markdown]
# ## 判断整数的符号
#
# 输入一个整数x，按照下面的规则输出表示符号的数字：
#
# $$
# sign(x)=\begin{cases}
# 1, x>0\\
# 0, x==0\\
# -1, x<0
# \end{cases}
# $$
#
# * IPO思维

# %% [markdown]
# ## 判断整数的符号
#
# $$
# sign(x)=\begin{cases}
# 1, x>0\\
# 0, x==0\\
# -1, x<0
# \end{cases}
# $$

# %%
x = int(input())
if x>0:
    r=1
elif x<0:
    r=-1
#else:    # 能否没有`else`？
#   r=0
print(r)
