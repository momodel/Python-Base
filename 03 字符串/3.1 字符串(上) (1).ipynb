# %% [markdown]
# ## 身份证
#
# ![](sfz.jpeg)
#
# * 如果要处理<span class="motutor-highlight motutor-id_6r1o652-id_ac9yabq"><i></i>居民身份号码？</span>，可以用整数吗

# %% [markdown]
# ## 字符串
#
# * <span class="motutor-highlight motutor-id_bftv6jw-id_u24ocld"><i></i>字符串</span>是用单引号或双引号括起来的一连串的字符
# * `input()`的结果就是用户输入的一行内容，作为一个字符串

# %%
a = input()
print(a)
print(type(a))

# %% [markdown]
# ## 字面量
#
# * <span class="motutor-highlight motutor-id_m6lh69z-id_2n7vjjf"><i></i>字面量</span>这个术语的意思就是写在程序代码里的人类可以阅读得到的值
#
# ```Python
# 6
# 7.2
# "hello"
# ```
# 这些都是字面量，它们可以参与运算，可以赋值给变量，可以传递给函数

# %% [markdown]
# ## 字符串字面量
#
# * 字符串字面量是用单引号或双引号括起来的一连串的字符
# ```
# "Hello"
# 'bye-bye'
# ```

# %% [markdown]
# 这些都是字符串字面量。字符串字面量两端的引号，是用来在源码中表示字符串字面量的，它们不构成字符串的组成成分，字符串在计算机内的数据并不包括两端的引号
#
# * 用`print()`输出字符串的时候，不会输出两端的引号
# * 在交互窗口直接输入变量名字检查的时候，会输出两端的引号以表明它的类型
# * `type()`可以用来检查它的类型
#
# *理解<span class="motutor-highlight motutor-id_9mfmvy8-id_k2rjf3v"><i></i>字面量和值之间的关系</span>非常重要*

# %% [markdown]
# 下一页我们学习字符串的下标
