# %% [markdown]
# ## <span class="motutor-highlight motutor-id_8po157a-id_4exd08g"><i></i>切片</span>
#
# * 从字符串中取出其中连续的一段的操作叫做切片`[1:3]`
# * 我们试过了从中间取8个字符的切片得到日期，我们试过了从开头取不包括最后一个字符的切片得到纯温度，如果想要取最后的几个字符呢？

# %% [markdown]
# | 0 |  1    |   2   |  3    |  4    |  5|  6  |  7  |
# | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- |
# | Z   |  h    |   e   |  j    |  i    | a  | n  |  g  |
# | -8     | -7    |   -6   | -5     | -4    |   -3   |  -2    |  -1  |
#
#
# * 初看起来这根本不是问题，比如要从`'Zhejiang'`里取出`'jiang'`，j是第3号元素，于是切片里的第一个数字是3，第二个数字呢？第二个数字表示在它前面切一刀，但是现在我们要在最后一个字符g的后面切一刀，这要怎么表达？-1表达的是最后一个元素，如果是`[3:-1]`，那么最后的g就弄丢了
# * g是第7号元素，它后面如果有的话，是第8号元素，那么[3:8]行不行？
# * 这个方法不通用，也不优雅，[3:]就够了

# %% [markdown]
# ## 切片
#
# * 从字符串中取出其中连续的一段的操作叫做切片
# * 切片由带有冒号的方括号来表达，如`s[a:b]`表示从`s[a]`到`s[b-1]`的内容取出来成为一个新的字符串
# * 切片中的元素编号也可以是负数，来表示从右边开始的编号
# * 当切片中的第一个元素编号不存在时，表示从头开始，当第二个编号不存在时，表示到最后一个为止
# * 切片还可以有<span class="motutor-highlight motutor-id_uq2qp36-id_6i2s8cr"><i></i>第二个冒号和第三个数据</span>，表示从切片头开始每次加多少

# %% [markdown]
# ## 切片
#
# `s='Zhejiang'`

# %%
s='Zhejiang'
s[::2]

# %% [markdown]
# * 切片使用负的下标访问`s[1:-3]`--> `'heji'`
# * 切片省略第2个下标，表示从第1个下标开始到最后一个的切片`s[2:]` --> `'ejing'`
# * 第1个下标为0时，可以省略
#     * `s[:3]` --> `'Zhe'`
# 	* `s[:-2]` --> `'Zhejia'`
# * 切片使用第3个参数，该参数表示切片选择元素的步长`s[0:5:2]` --> `'Zei'`
# * 切片使用第3个参数为负数时，表示逆向取切片
#     * `s[-1:0:-1] --> `'gnaijeh'`
# 	* `s[::-1]` --> `'gnaijehZ'`

# %% [markdown]
# 下一页我们学习字符串的拼接和转义字符
