# %% [markdown]
# ## <span class="motutor-highlight motutor-id_pztj386-id_s5p4v2s"><i></i>判断空表</span>

# %%
t = []
print(t==[])
print(len(t)==0)
print(not t)

# %% [markdown]
# * 任何值都可能被直接当作逻辑值
# * 0、空表、空字符串被当作是`False`，其他值都是`True`
#
# * 以下代码为什么错了：
# `if c='C' or 'c':`

# %% [markdown]
# ## <span class="motutor-highlight motutor-id_nhks3os-id_gm1x4x8"><i></i>抛空一个表</span>

# %%
line = input().split()
while line:
    print(line.pop(0))

# %% [markdown]
# * 如果最后一句是`print(line.pop())`会怎样？

# %% [markdown]
# ## <span class="motutor-highlight motutor-id_hi1n4xm-id_xxszt31"><i></i>猴子选大王</span>
#
# - 一群猴子要选新猴王。新猴王的选择方法是：让N只候选猴子围成一圈，从某位置起顺序编号为1~N号。从第1号开始报数，每轮从1报到3，凡报到3的猴子即退出圈子，接着又从紧邻的下一只猴子开始同样的报数。如此不断循环，最后剩下的一只猴子就选为猴王。请问是原来第几号猴子当选猴王？

# %%
n = int(input())
lst = list(range(1,n+1))
i=-1
while len(lst)>1:
    i += 3
    i %= len(lst)
    del lst[i]
    i -= 1
print(lst[0])
