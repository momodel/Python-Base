# %% [markdown]
# ## <span class="motutor-highlight motutor-id_6zzaa6y-id_o5yn58e"><i></i>预先告知数据&每行不确定</span>
#
# >9</br>
# 1 2 3</br>
# 4 5</br>
# 6 7 8 9</br>
#
# * 能否用for in range？

# %% [markdown]
# ## 预先告知数据&每行不确定
#
# >9</br>
# 1 2 3</br>
# 4 5</br>
# 6 7 8 9</br>

# %%
lst = []
n = int(input())
m = list(map(int, input().split()))
lst.extend(m)
n -= len(m)
if n==0:
    break

# %% [markdown]
# * 首先考虑第一次读入时怎么做

# %% [markdown]
# ## 预先告知数据&每行不确定
#
# >9</br>
# 1 2 3</br>
# 4 5</br>
# 6 7 8 9</br>

# %%
lst = []
n = int(input())
while True:
    m = list(map(int, input().split()))
    lst.extend(m)
    n -= len(m)
    if n==0:
        break

# %% [markdown]
# ## 真实实验数据
#
# * input()是从标准输入（不是键盘）读，执行python程序时可以用重定向
# * 虽然可以去数个数量，但是懒得数，所以都是读到没数据了算结束
# * 怎么知道没数据了，**文件**那章会讲打开文件时如何知道文件读完了
# * 标准输入时，可以用Ctrl-Z（Unix，包括macOS用Ctrl-D）来结束标准输入

# %% [markdown]
# ## 小结
#
# * 重复的次数是预知的，可以用`for in range`
# * 先写出第一个数据要做的动作
# * 然后用`while True:`包围起来
# * 找出不再继续的条件，做`break`
