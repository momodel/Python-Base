# %% [markdown]
# <center style="font-size:30px">使用列表的计算（上）</center>

# %% [markdown]
# ## <span class="motutor-highlight motutor-id_a1krkv6-id_9vpbjxe"><i></i>创建空列表</span>

# %%
t = []
t = list()

# %% [markdown]
# ## `list()`
#
# * `list()`可以将其他类型转换成列表，比如把字符串转换成列表

# %%
s = 'Hello'
t = list(s)
t

# %% [markdown]
# ## “<span class="motutor-highlight motutor-id_fikg1r3-id_n26frjc"><i></i>列表字面量</span>”
#
# * “列表字面量”是一个表达式而非常量

# %%
a = 2
t = [a, a+1, 3]
t
